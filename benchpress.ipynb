# %% [markdown]
# # Benchpress
#
# The goal of this noteboook is to set up and run benchpress with some

# %%
# !git clone https://github.com/anadim/llm-benchmark-matrix.git
# Out:
# Cloning into 'llm-benchmark-matrix'...
# remote: Enumerating objects: 154, done.
# remote: Counting objects: 100% (154/154), done.
# remote: Compressing objects:  66% (78/118)
# remote: Compressing objects: 100% (118/118), done.
# Receiving objects:  18% (28/154)
# Receiving objects:  35% (54/154)
# Receiving objects:  83% (128/154)
# remote: Total 154 (delta 49), reused 137 (delta 32), pack-reused 0 (from 0)
# Receiving objects: 100% (154/154), 4.26 MiB | 28.33 MiB/s, done.
# Resolving deltas: 100% (49/49), done.
