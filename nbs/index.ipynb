# %%
#| hide
from evaluating_agi.core import *

# %% [markdown]
# # evaluating-agi
#
# >

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install evaluating_agi in Development mode

# %% [markdown]
# ```sh
# # make sure evaluating_agi package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to evaluating_agi
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/kafkasl/evaluating-agi.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c kafkasl evaluating_agi
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install evaluating_agi
# ```
#
#
# [repo]: https://github.com/kafkasl/evaluating-agi
# [docs]: https://kafkasl.github.io/evaluating-agi/
# [pypi]: https://pypi.org/project/evaluating-agi/
# [conda]: https://anaconda.org/kafkasl/evaluating-agi

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/kafkasl/evaluating-agi
# [docs]: https://kafkasl.github.io/evaluating-agi/
# [pypi]: https://pypi.org/project/evaluating-agi/
# [conda]: https://anaconda.org/kafkasl/evaluating-agi

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
